# %%
# !pip install fredapi
# Out:
# ...
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)

# %%
from fredapi import Fred
fred = Fred(api_key='5bcbfae12c3c9d16879fafa1c279fed2')
data = fred.get_series('SP500')

# %%
dict_cur = {'EUR': {'id': 'DEXUSEU', 'color': 'darkblue'},
            'GBP': {'id': 'DEXUSUK', 'color': 'teal'},
            'AUD': {'id': 'DEXUSAL', 'color': 'brown'},
            'CAD': {'id': 'DEXCAUS', 'color': 'blue'},
            'JPY': {'id': 'DEXJPUS', 'color': 'salmon'},
            'RMB': {'id': 'DEXCHUS', 'color': 'red'},
            'KRW': {'id': 'DEXKOUS', 'color': 'orange'},
            'SGD': {'id': 'DEXSIUS', 'color': 'yellow'},
            'NTD': {'id': 'DEXTAUS', 'color': 'purple'},
            'HKD': {'id': 'DEXHKUS', 'color': 'firebrick'},
            'THB': {'id': 'DEXTHUS', 'color': 'black'},
            }

# %%
for key, subdict in dict_cur.items():
    if key in ['EUR', 'GBP', 'AUD']: 
        data = (1 / fred.get_series(subdict['id']))
    else:
        data = (fred.get_series(subdict['id']))
    subdict['data'] = data.rename(key)

# %%
import pandas as pd
df_full = pd.concat([subdict['data'] for subdict in dict_cur.values()], axis = 1)

# %%
df_full
# Out:
#                  EUR       GBP       AUD     CAD     JPY     RMB      KRW  \
# 1971-01-04       NaN  0.417746  0.898715  1.0109  357.73     NaN      NaN
# 1971-01-05       NaN  0.417554  0.898311  1.0102  357.81     NaN      NaN
# 1971-01-06       NaN  0.417240  0.897666  1.0106  357.86     NaN      NaN
# 1971-01-07       NaN  0.417310  0.897827  1.0148  357.87     NaN      NaN
# 1971-01-08       NaN  0.417153  0.898957  1.0154  357.82     NaN      NaN
# ...              ...       ...       ...     ...     ...     ...      ...
# 2023-02-06  0.932662  0.832709  1.455816  1.3442  132.76  6.7918  1252.61
# 2023-02-07  0.934143  0.832432  1.444043  1.3440  131.37  6.7910  1255.53
# 2023-02-08  0.931619  0.826925  1.440715  1.3430  131.27  6.7890  1260.03
# 2023-02-09  0.929282  0.822571  1.435956  1.3428  130.98  6.7782  1259.67
# 2023-02-10  0.937207  0.829119  1.445296  1.3363  131.50  6.8106  1264.15
#
#                SGD    NTD     HKD    THB
# ...

# %%
# YTD
df = df_full.loc['2023-01-01':].dropna()
df = df / df.iloc[0] *100 - 100

# %%
# QTD
from datetime import date
df = df_full.loc[str(date(today.year,(today.month-1)//3 + 1,1)):].dropna()
df = df / df.iloc[0] * 100 - 100

# %%
# MTD
from datetime import date
df = df_full.loc[str(date(today.year,today.month,1)):].dropna()
df = df / df.iloc[0] * 100 - 100

# %%
import plotly.graph_objects as go

fig = go.Figure()
x = df.index

for col in df.iloc[-1].sort_values(ascending = False).index: # Sorted
    fig.add_trace(go.Scatter(x=x, y=df[col], name=col, line=dict(color=dict_cur[col]['color'], width=4)))

# %%
fig.show()
# Out:
# <div>                            <div id="195c6cdf-9a25-4370-bee9-277b90c55e46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("195c6cdf-9a25-4370-bee9-277b90c55e46")) {                    Plotly.newPlot(                        "195c6cdf-9a25-4370-bee9-277b90c55e46",                        [{"line":{"color":"salmon","width":4},"name":"JPY","x":["2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","2023-01-17T00:00:00","2023-01-18T00:00:00","2023-01-19T00:00:00","2023-01-20T00:00:00","2023-01-23T00:00:00","2023-01-24T00:00:00","2023-01-25T00:00:00","2023-01-26T00:00:00","2023-01-27T00:00:00","2023-01-30T00:0
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Bar(
            x=df.iloc[-1].sort_values(),
            y=df.iloc[-1].sort_values().index,
            orientation='h'))

fig.show()
# Out:
# <div>                            <div id="a6f1d10b-556d-44a5-817f-5ca5b45a343b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6f1d10b-556d-44a5-817f-5ca5b45a343b")) {                    Plotly.newPlot(                        "a6f1d10b-556d-44a5-817f-5ca5b45a343b",                        [{"orientation":"h","x":[-2.7316086139615265,-2.2028688524590194,-1.9488074461896474,-1.7258222077499283,-1.4883922759817807,-1.070870826206587,-1.040299906279273,-0.7544979686593081,-0.5467705137282621,0.48643735838913926,0.5121149583428632],"y":["AUD","CAD","THB","NTD","RMB","SGD","EUR","GBP","KRW","HKD","JPY"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"
# ...
